# %% [markdown]
# <a href="https://colab.research.google.com/github/Kotte-Shivani/NASSCOM/blob/main/student_details.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("/content/sample_data/student_details.csv")
df.head()
# Out:
#       name roll_number  phone_number
# 0  shivani  25wh1a05ah    9857684567
# 1  bhavani  25wh1a05a9   96874425656
# 2   renuka  25wh1a05a5    9783542675
