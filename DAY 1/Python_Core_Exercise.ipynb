# %% [markdown]
# <a href="https://colab.research.google.com/github/Kotte-Shivani/NASSCOM/blob/main/DAY%201/Python_Core_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import datetime
import random

print("--- Intermediate Python Core Exercise ---")
print("This exercise covers Python fundamentals, data structures, functions,")
print("core libraries (os, datetime, random), file handling, and exception handling.")
print("Estimated completion time: 3-4 hours.")
print("------------------------------------------")

DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0),
    'Humidity_Sensor': (30.0, 80.0),
    'Pressure_Sensor': (980.0, 1030.0),
    'Light_Sensor': (100, 1000)
}

print("\n--- Task 1: Data Generation and Basic Structures ---")

raw_sensor_data = []

start_time = datetime.datetime.now()

for i in range(100):
    device_type = random.choice(DEVICE_TYPES)
    location = random.choice(LOCATIONS)
    min_val, max_val = READING_RANGES[device_type]
    value = round(random.uniform(min_val, max_val), 2)
    timestamp = (start_time + datetime.timedelta(minutes=i)).strftime("%Y-%m-%d %H:%M:%S")
    device_id = f"DEV{i+1:03d}"
    raw_sensor_data.append((timestamp, device_id, device_type, location, value))

temperature_readings = []

for reading in raw_sensor_data:
    if reading[2] == "Temperature_Sensor":
        temperature_readings.append({
            "timestamp": reading[0],
            "device_id": reading[1],
            "location": reading[3],
            "temperature_celsius": reading[4]
        })

unique_locations = set()

for reading in raw_sensor_data:
    unique_locations.add(reading[3])

device_stats = {}

for device in DEVICE_TYPES:
    device_stats[device] = (float("inf"), float("-inf"))

for reading in raw_sensor_data:
    device = reading[2]
    value = reading[4]
    minimum, maximum = device_stats[device]
    device_stats[device] = (min(minimum, value), max(maximum, value))

print("\n--- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---")

sample_string = "PythonProgrammingIsFun"

sliced_readings_1 = raw_sensor_data[9:20]
sliced_readings_2 = raw_sensor_data[::5]

substring_1 = sample_string[6:17]
substring_2 = sample_string[:6][::-1]

fifth_reading_device_type = raw_sensor_data[4][2]
device_type_suffix = fifth_reading_device_type[-6:]

print(sliced_readings_1)
print(sliced_readings_2)
print(substring_1)
print(substring_2)
print(fifth_reading_device_type)
print(device_type_suffix)

print("\n--- Task 2: Function Definitions and Usage ---")

def get_readings_by_location(readings_list, target_location):
    return [reading for reading in readings_list if reading[3] == target_location]

def calculate_average_temperature(temp_data_list):
    if len(temp_data_list) == 0:
        return 0.0
    total = sum(item["temperature_celsius"] for item in temp_data_list)
    return total / len(temp_data_list)

def generate_report_line(reading_dict):
    return f"[{reading_dict['timestamp']}] Device {reading_dict['device_id']} at {reading_dict['location']}: {reading_dict['temperature_celsius']}°C"

print(get_readings_by_location(raw_sensor_data, "Lab1")[:3])
print(calculate_average_temperature(temperature_readings))

print("\n--- Task 3: Core Library Usage ---")

reports_dir = "sensor_reports"

if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print(f"\nDirectory '{reports_dir}' created.")
else:
    print(f"\nDirectory '{reports_dir}' already exists.")

if len(raw_sensor_data) > 1:
    first_timestamp_str = raw_sensor_data[0][0]
    last_timestamp_str = raw_sensor_data[-1][0]

    date_format = "%Y-%m-%d %H:%M:%S"

    first_dt = datetime.datetime.strptime(first_timestamp_str, date_format)
    last_dt = datetime.datetime.strptime(last_timestamp_str, date_format)

    duration = last_dt - first_dt

    days = duration.days
    seconds = duration.total_seconds()
    hours = int(seconds // 3600) % 24
    minutes = int((seconds % 3600) // 60)

    print(f"\nDuration of data collection: {days} days, {hours} hours, {minutes} minutes.")
else:
    print("\nNot enough data to calculate duration.")

random_values = [random.randint(100, 200) for _ in range(5)]

print(random_values)

print("\n--- Task 4: File I/O ---")

report_filename = os.path.join(reports_dir, "temperature_report.txt")

try:
    with open(report_filename, "w") as f:
        for reading in temperature_readings:
            f.write(generate_report_line(reading) + "\n")
    print(f"\nTemperature report written to '{report_filename}'.")
except IOError as e:
    print(f"\nError writing file '{report_filename}': {e}")

try:
    with open(report_filename, "r") as f:
        read_report_lines = f.readlines()

    print("\nFirst 3 lines:")
    for line in read_report_lines[:3]:
        print(line.strip())

except IOError as e:
    print(f"\nError reading file: {e}")

print("\n--- Exercise Complete! ---")
print("Great job completing the intermediate Python exercise.")
print("Review your code and outputs to ensure correctness and understanding of all concepts.")
print("Consider adding more complex scenarios or user inputs for further practice.")
# Out:
# --- Intermediate Python Core Exercise ---
# This exercise covers Python fundamentals, data structures, functions,
# core libraries (os, datetime, random), file handling, and exception handling.
# Estimated completion time: 3-4 hours.
# ------------------------------------------
#
# --- Task 1: Data Generation and Basic Structures ---
#
# --- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---
# [('2026-07-24 17:00:04', 'DEV010', 'Temperature_Sensor', 'Lab1', 18.5), ('2026-07-24 17:01:04', 'DEV011', 'Humidity_Sensor', 'Warehouse', 45.94), ('2026-07-24 17:02:04', 'DEV012', 'Pressure_Sensor', 'Lab1', 987.25), ('2026-07-24 17:03:04', 'DEV013', 'Humidity_Sensor', 'Lab2', 45.83), ('2026-07-24 17:04:04', 'DEV014', 'Pressure_Sensor', 'Warehouse', 1001.27), ('2026-07-24 17:05:04', 'DEV015', 'Pressure_Sensor', 'OfficeA', 1000.29), ('2026-07-24 17:06:04', 'DEV016', 'Pressure_Sensor', 'OfficeB', 985.53), ('2026-07-24 17:07:04', 'DEV017', 'Temperature_Sensor', 'Lab1', 23.21), ('2026-07-24 17:08:04', 'DEV018', 'Light_Sensor', 'Lab2', 249.01), ('2026-07-24 17:09:04', 'DEV019', 'Pressure_Sensor', 'Lab1', 1016.68), ('2026-07-24 17:10:04', 'DEV020', 'Light_Sensor', 'Lab1', 309.13)]
# [('2026-07-24 16:51:04', 'DEV001', 'Light_Sensor', 'OfficeB', 290.63), ('2026-07-24 16:56:04', 'DEV006', 'Temperature_Sensor', 'Warehouse', 19.94), ('2026-07-24 17:01:04', 'DEV011', 'Humidity_Sensor', 'Warehouse', 45.94), ('2026-07-24 17:06:04', 'DEV016', 'Pressure_Sensor', 'OfficeB', 985.53), ('2026-07-24 17:11:04', 'DEV021', 'Light_Sensor', 'OfficeA', 520.9), ('2026-07-24 17:16:04', 'DEV026', 'Humidity_Sensor', 'Warehouse', 63.93), ('2026-07-24 17:21:04', 'DEV031', 'Pressure_Sensor', 'Warehouse', 996.3), ('2026-07-24 17:26:04', 'DEV036', 'Humidity_Sensor', 'Lab2', 38.59), ('2026-07-24 17:31:04', 'DEV041', 'Humidity_Sensor', 'OfficeA', 36.68), ('2026-07-24 17:36:04', 'DEV046', 'Temperature_Sensor', 'Lab1', 25.24), ('2026-07-24 17:41:04', 'DEV051', 'Temperature_Sensor', 'OfficeA', 25.21), ('2026-07-24 17:46:04', 'DEV056', 'Temperature_Sensor', 'Lab2', 26.19), ('2026-07-24 17:51:04', 'DEV061', 'Temperature_Sensor', 'OfficeB', 27.94), ('2026-07-24 17:56:04', 'DEV066', 'Humidity_Sensor', 'Warehouse', 68.16), ('2026-07-24 18:01:04', 'DEV071', 'Pressure_Sensor', 'Lab2', 1028.82), ('2026-07-24 18:06:04', 'DEV076', 'Temperature_Sensor', 'Warehouse', 23.71), ('2026-07-24 18:11:04', 'DEV081', 'Humidity_Sensor', 'OfficeA', 44.28), ('2026-07-24 18:16:04', 'DEV086', 'Pressure_Sensor', 'OfficeB', 1016.35), ('2026-07-24 18:21:04', 'DEV091', 'Pressure_Sensor', 'Lab1', 1009.31), ('2026-07-24 18:26:04', 'DEV096', 'Humidity_Sensor', 'Lab2', 31.13)]
# Programming
# nohtyP
# Temperature_Sensor
# Sensor
#
# --- Task 2: Function Definitions and Usage ---
# [('2026-07-24 16:52:04', 'DEV002', 'Pressure_Sensor', 'Lab1', 1019.63), ('2026-07-24 16:53:04', 'DEV003', 'Pressure_Sensor', 'Lab1', 997.63), ('2026-07-24 17:00:04', 'DEV010', 'Temperature_Sensor', 'Lab1', 18.5)]
# 23.481666666666666
#
# --- Task 3: Core Library Usage ---
#
# Directory 'sensor_reports' created.
#
# Duration of data collection: 0 days, 1 hours, 39 minutes.
# [165, 173, 138, 149, 144]
#
# --- Task 4: File I/O ---
#
# Temperature report written to 'sensor_reports/temperature_report.txt'.
#
# First 3 lines:
# [2026-07-24 16:55:04] Device DEV005 at Lab2: 21.16°C
# [2026-07-24 16:56:04] Device DEV006 at Warehouse: 19.94°C
# [2026-07-24 16:57:04] Device DEV007 at Lab2: 29.93°C
#
# --- Exercise Complete! ---
# Great job completing the intermediate Python exercise.
# Review your code and outputs to ensure correctness and understanding of all concepts.
# Consider adding more complex scenarios or user inputs for further practice.
